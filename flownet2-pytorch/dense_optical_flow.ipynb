# %%
## import numpy as np
import matplotlib.pyplot as plt
import cv2

def read_flo_file(filename):
    with open(filename, 'rb') as f:
        magic = np.fromfile(f, np.float32, count=1)
        if magic != 202021.25:
            raise ValueError('Magic number incorrect. Invalid .flo file')
        width = np.fromfile(f, np.int32, count=1)[0]
        height = np.fromfile(f, np.int32, count=1)[0]
        data = np.fromfile(f, np.float32, count=2 * width * height)
        flow = np.resize(data, (height, width, 2))
        return flow

def calculate_magnitude(flow):
    magnitude = np.sqrt(flow[..., 0]**2 + flow[..., 1]**2)
    return magnitude

def calculate_average_magnitude(magnitude):
    average_magnitude = np.mean(magnitude)
    return average_magnitude

def calculate_total_movement(magnitude):
    total_movement = np.sum(magnitude)
    return total_movement
    
def visualize_flow(flow):
    hsv = np.zeros((flow.shape[0], flow.shape[1], 3), dtype=np.uint8)
    mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    hsv[..., 0] = ang * 180 / np.pi / 2
    hsv[..., 1] = 255
    hsv[..., 2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)
    rgb = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    plt.imshow(rgb)
    plt.show()

# .flo 파일 경로
flo_file = 'output0430_3/inference/run.epoch-0-flow-field/000325.flo'

# .flo 파일 읽기
flow_data = read_flo_file(flo_file)

# Optical Flow 시각화
visualize_flow(flow_data)

# 벡터 크기 계산
magnitude = calculate_magnitude(flow_data)

# 벡터 크기의 평균 계산
average_magnitude = calculate_average_magnitude(magnitude)
print(f'Average Magnitude: {average_magnitude}')

# 전체 이동 거리 합 계산
total_movement = calculate_total_movement(magnitude)
print(f'Total Movement: {total_movement}')
# Out:
# Average Magnitude: 224.8907012939453
# Total Movement: 994844480.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

def read_flo_file(filename):
    with open(filename, 'rb') as f:
        magic = np.fromfile(f, np.float32, count=1)
        if magic != 202021.25:
            raise ValueError('Magic number incorrect. Invalid .flo file')
        width = np.fromfile(f, np.int32, count=1)[0]
        height = np.fromfile(f, np.int32, count=1)[0]
        data = np.fromfile(f, np.float32, count=2 * width * height)
        flow = np.resize(data, (height, width, 2))
        return flow

def visualize_flow(flow):
    hsv = np.zeros((flow.shape[0], flow.shape[1], 3), dtype=np.uint8)
    mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    hsv[..., 0] = ang * 180 / np.pi / 2
    hsv[..., 1] = 255
    hsv[..., 2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)
    rgb = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    plt.imshow(rgb)
    plt.show()

# .flo 파일 경로
flo_file = 'output2/inference/run.epoch-0-flow-field/000319.flo'

# .flo 파일 읽기
flow_data = read_flo_file(flo_file)

# Optical Flow 시각화
visualize_flow(flow_data)

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

def read_flo_file(filename):
    with open(filename, 'rb') as f:
        magic = np.fromfile(f, np.float32, count=1)
        if magic != 202021.25:
            raise ValueError('Magic number incorrect. Invalid .flo file')
        width = np.fromfile(f, np.int32, count=1)[0]
        height = np.fromfile(f, np.int32, count=1)[0]
        data = np.fromfile(f, np.float32, count=2 * width * height)
        flow = np.resize(data, (height, width, 2))
        return flow

def visualize_flow(flow, title='Optical Flow'):
    hsv = np.zeros((flow.shape[0], flow.shape[1], 3), dtype=np.uint8)
    mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    hsv[..., 0] = ang * 180 / np.pi / 2
    hsv[..., 1] = 255
    hsv[..., 2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)
    rgb = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    plt.imshow(rgb)
    plt.title(title)
    plt.show()

def calculate_flow_difference(flow1, flow2):
    return flow2 - flow1

# 이전 프레임과 현재 프레임의 .flo 파일 경로
flo_file_previous = 'output/inference/run.epoch-0-flow-field/000310.flo'
flo_file_current = 'output/inference/run.epoch-0-flow-field/000311.flo'

# .flo 파일 읽기
flow_data_previous = read_flo_file(flo_file_previous)
flow_data_current = read_flo_file(flo_file_current)

# Optical Flow 차이 계산
flow_difference = calculate_flow_difference(flow_data_previous, flow_data_current)

# Optical Flow 시각화
visualize_flow(flow_data_previous, title='Previous Frame Optical Flow')
visualize_flow(flow_data_current, title='Current Frame Optical Flow')
visualize_flow(flow_difference, title='Optical Flow Difference')

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

def read_flo_file(filename):
    with open(filename, 'rb') as f:
        magic = np.fromfile(f, np.float32, count=1)
        if magic != 202021.25:
            raise ValueError('Magic number incorrect. Invalid .flo file')
        width = np.fromfile(f, np.int32, count=1)[0]
        height = np.fromfile(f, np.int32, count=1)[0]
        data = np.fromfile(f, np.float32, count=2 * width * height)
        flow = np.resize(data, (height, width, 2))
        return flow

def visualize_flow(flow, title='Optical Flow'):
    hsv = np.zeros((flow.shape[0], flow.shape[1], 3), dtype=np.uint8)
    mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    hsv[..., 0] = ang * 180 / np.pi / 2
    hsv[..., 1] = 255
    hsv[..., 2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)
    rgb = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    plt.imshow(rgb)
    plt.title(title)
    plt.show()

def calculate_flow_difference(flow1, flow2):
    return flow2 - flow1

def calculate_average_magnitude_difference(flow_difference):
    mag_diff = np.sqrt(flow_difference[..., 0]**2 + flow_difference[..., 1]**2)
    average_mag_diff = np.mean(mag_diff)
    return average_mag_diff

# 이전 프레임과 현재 프레임의 .flo 파일 경로
flo_file_previous = 'output/inference/run.epoch-0-flow-field/000901.flo'
flo_file_current = 'output/inference/run.epoch-0-flow-field/000902.flo'

# .flo 파일 읽기
flow_data_previous = read_flo_file(flo_file_previous)
flow_data_current = read_flo_file(flo_file_current)

# Optical Flow 차이 계산
flow_difference = calculate_flow_difference(flow_data_previous, flow_data_current)

# Optical Flow 시각화
visualize_flow(flow_data_previous, title='Previous Frame Optical Flow')
visualize_flow(flow_data_current, title='Current Frame Optical Flow')
visualize_flow(flow_difference, title='Optical Flow Difference')

# 평균 크기 차이 계산
average_mag_diff = calculate_average_magnitude_difference(flow_difference)
print(f'Average Magnitude Difference: {average_mag_diff}')
# Out:
# Average Magnitude Difference: 221.0135040283203

# %%
import os

def list_files_with_index(directory):
    files = os.listdir(directory)
    indexed_files = [(index, file) for index, file in enumerate(files)]
    return indexed_files

# 디렉토리 경로
directory_path = '/ext/BMW_sampling/20240502/3b90b8b6-0454-402d-a1c2-018eadb1aea2/2024-04-26_10-44-20+02-00--7K90070--3b90b8b6-0454-402d-a1c2-018eadb1aea2/LIDAR_TOP_CENTRAL/__RV__front'

# 디렉토리의 파일 인덱스와 이름을 가져오기
indexed_files = list_files_with_index(directory_path)
# Out:
# <class 'tuple'>

# %%
import os

def list_files_with_index(directory):
    files = sorted(os.listdir(directory))
    indexed_files = [(index, file) for index, file in enumerate(files)]
    return indexed_files

def find_tuples_with_substring(tuples_list, substring):
    return [tup for tup in tuples_list if substring in tup[1]]

# 디렉토리 경로
directory_path ='/ext/BMW_sampling/20240430/3607d9be-e012-42c3-a555-018ead8423fe/2024-04-26_10-40-33+02-00--7K90070--3607d9be-e012-42c3-a555-018ead8423fe/LIDAR_TOP_CENTRAL/__RV__front'

# 디렉토리의 파일 인덱스와 이름을 가져오기
indexed_files = list_files_with_index(directory_path)

# 특정 문자열이 포함된 튜플 찾기
substring = 'L_12129424921961580_F_12129424915061014.jpg'
matching_tuples = find_tuples_with_substring(indexed_files, substring)

# 결과 출력
for index, file in matching_tuples:
    print(f'Index: {index}, File: {file}')
# Out:
# Index: 324, File: L_12129424921961580_F_12129424915061014.jpg

# %%
import numpy as np
import os

def read_flo_file(filename):
    with open(filename, 'rb') as f:
        magic = np.fromfile(f, np.float32, count=1)
        if magic != 202021.25:
            raise ValueError('Magic number incorrect. Invalid .flo file')
        width = np.fromfile(f, np.int32, count=1)[0]
        height = np.fromfile(f, np.int32, count=1)[0]
        data = np.fromfile(f, np.float32, count=2 * width * height)
        flow = np.resize(data, (height, width, 2))
        return flow

def calculate_magnitude(flow):
    magnitude = np.sqrt(flow[..., 0]**2 + flow[..., 1]**2)
    return magnitude

def calculate_average_magnitude(magnitude):
    average_magnitude = np.mean(magnitude)
    return average_magnitude

def calculate_total_movement(magnitude):
    total_movement = np.sum(magnitude)
    return total_movement

# .flo 파일 경로
flo_file = 'output2/inference/run.epoch-0-flow-field/000319.flo'

# .flo 파일 읽기
flow_data = read_flo_file(flo_file)

# 벡터 크기 계산
magnitude = calculate_magnitude(flow_data)

# 벡터 크기의 평균 계산
average_magnitude = calculate_average_magnitude(magnitude)
print(f'Average Magnitude: {average_magnitude}')

# 전체 이동 거리 합 계산
total_movement = calculate_total_movement(magnitude)
print(f'Total Movement: {total_movement}')
# Out:
# Average Magnitude: 158.82630920410156
# Total Movement: 702596800.0
